# %% [markdown]
# <a href="https://colab.research.google.com/github/nngiabao/AIDevFundamental/blob/main/StudentPerformancePredict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d mrsimple07/student-exam-performance-prediction
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mrsimple07/student-exam-performance-prediction
# License(s): apache-2.0
# ...
#   0% 0.00/19.3k [00:00<?, ?B/s]
# 100% 19.3k/19.3k [00:00<00:00, 54.1MB/s]

# %%
# !unzip student-exam-performance-prediction.zip -d dataset
# Out:
# Archive:  student-exam-performance-prediction.zip
#   inflating: dataset/student_exam_data.csv
#   inflating: dataset/student_exam_data_new.csv

# %%
#
